# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pickle

with open('/content/gdrive/MyDrive/Result/Proposed PMTL/task_train_losses_pref_new_1.pkl', 'wb') as fp:
    pickle.dump(task_train_losses_pref, fp)
with open('/content/gdrive/MyDrive/Result/Proposed PMTL/train_accs_pref_new_1.pkl', 'wb') as fp:
    pickle.dump(train_accs_pref, fp)
with open('/content/gdrive/MyDrive/Result/Proposed PMTL/task_test_losses_pref_new_1.pkl', 'wb') as fp:
    pickle.dump(task_test_losses_pref, fp)
with open('/content/gdrive/MyDrive/Result/Proposed PMTL/test_accs_pref_new_1.pkl', 'wb') as fp:
    pickle.dump(test_accs_pref, fp)
with open('/content/gdrive/MyDrive/Result/Proposed PMTL/learning_rate_pref_new_1.pkl', 'wb') as fp:
    pickle.dump(learning_rate_pref, fp)

# %% [markdown]
# # Đồ thị

# %%
import pickle

with open('/content/gdrive/MyDrive/Result/Drug/Drug_Proposed/task_train_losses_pref_4.pkl', 'rb') as fp:
  task_train_losses_pref = pickle.load(fp)
with open('/content/gdrive/MyDrive/Result/Drug/Drug_Proposed/train_accs_pref_4.pkl', 'rb') as fp:
  train_accs_pref = pickle.load(fp)
with open('/content/gdrive/MyDrive/Result/Drug/Drug_Proposed/task_test_losses_pref_4.pkl', 'rb') as fp:
  task_test_losses_pref = pickle.load(fp)
with open('/content/gdrive/MyDrive/Result/Drug/Drug_Proposed/test_accs_pref_4.pkl', 'rb') as fp:
  test_accs_pref = pickle.load(fp)
with open('/content/gdrive/MyDrive/Result/Drug/Drug_Proposed/learning_rate_pref_4.pkl', 'rb') as fp:
  learning_rate_pref = pickle.load(fp)

# %%
for i in test_accs_pref:
  print(i[-1])
# Out:
# [0.82245169 0.87210928]
# [0.80875551 0.87071098]
# [0.83962569 0.86769926]
# [0.86196264 0.86199849]
# [0.86285899 0.85952458]

# %%
pref = 1

# %% [markdown]
# ##Loss function

# %%
loss_1_train = []
loss_2_train = []
loss_1_test = []
loss_2_test = []
for i, j in zip(task_train_losses_pref[pref], task_test_losses_pref[pref]):
  loss_1_train.append(i[0])
  loss_2_train.append(i[1])
  loss_1_test.append(j[0])
  loss_2_test.append(j[1])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 8))

import numpy as np
x = np.arange(0,52,2)

plt.plot(x, loss_1_train, color = 'r', label = 'Loss 1 Training')
plt.plot(x, loss_2_train, color = 'g', label = 'Loss 2 Training')
plt.plot(x, loss_1_test, color = 'blue', label = 'Loss 1 Testing')
plt.plot(x, loss_2_test, color = 'black', label = 'Loss 2 Testing')
# plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel(r'Loss Function')

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Accuracy

# %%
acc_1_train = []
acc_2_train = []
acc_1_test = []
acc_2_test = []
for i, j in zip(train_accs_pref[pref], test_accs_pref[pref]):
  acc_1_train.append(i[0])
  acc_2_train.append(i[1])
  acc_1_test.append(j[0])
  acc_2_test.append(j[1])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 8))

import numpy as np
x = np.arange(0, 52, 2)

plt.plot(x, acc_1_train, color = 'r', label = 'Acc 1 Training')
plt.plot(x, acc_2_train, color = 'g', label = 'Acc 2 Training')
plt.plot(x, acc_1_test, color = 'blue', label = 'Acc 1 Testing')
plt.plot(x, acc_2_test, color = 'black', label = 'Acc 2 Testing')
# plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel(r'Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #So sánh với PMTL - Không Adaptive

# %%
import pickle

with open('/content/gdrive/MyDrive/Result/Drug/PMTL/task_train_losses_no_1.pkl', 'rb') as fp:
  task_train_losses_pref_non = pickle.load(fp)
with open('/content/gdrive/MyDrive/Result/Drug/PMTL/train_accs_no_1.pkl', 'rb') as fp:
  train_accs_pref_non = pickle.load(fp)
with open('/content/gdrive/MyDrive/Result/Drug/PMTL/task_test_losses_no_1.pkl', 'rb') as fp:
  task_test_losses_pref_non = pickle.load(fp)
with open('/content/gdrive/MyDrive/Result/Drug/PMTL/test_accs_no_1.pkl', 'rb') as fp:
  test_accs_pref_non = pickle.load(fp)

# %%
acc_1_train_non = []
acc_2_train_non = []
acc_1_test_non = []
acc_2_test_non = []
for i, j in zip(train_accs_pref_non[pref], test_accs_pref_non[pref]):
  acc_1_train_non.append(i[0])
  acc_2_train_non.append(i[1])
  acc_1_test_non.append(j[0])
  acc_2_test_non.append(j[1])
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 8))
plt.plot(x, acc_1_train_non, color = 'r', label = 'Acc 1 Training Non Adaptive')
plt.plot(x, acc_2_train_non, color = 'g', label = 'Acc 2 Training Non Adaptive')
plt.plot(x, acc_1_test_non, color = 'blue', label = 'Acc 1 Testing Non Adaptive')
plt.plot(x, acc_2_test_non, color = 'black', label = 'Acc 2 Testing Non Adaptive')
# plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel(r'Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# %%
loss_1_train_non = []
loss_2_train_non = []
loss_1_test_non = []
loss_2_test_non = []
for i, j in zip(task_train_losses_pref_non[pref], task_test_losses_pref_non[pref]):
  loss_1_train_non.append(i[0])
  loss_2_train_non.append(i[1])
  loss_1_test_non.append(j[0])
  loss_2_test_non.append(j[1])
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 8))
plt.plot(x, loss_1_train_non, color = 'r', label = 'Loss 1 Training Non Adaptive')
plt.plot(x, loss_2_train_non, color = 'g', label = 'Loss 2 Training Non Adaptive')
plt.plot(x, loss_1_test_non, color = 'blue', label = 'Loss 1 Testing Non Adaptive')
plt.plot(x, loss_2_test_non, color = 'black', label = 'Loss 2 Testing Non Adaptive')
# plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel(r'Loss function')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 8))

plt.plot(x, loss_1_test, color = 'blue', label = 'Loss 1 Testing')
plt.plot(x, loss_2_test, color = 'black', label = 'Loss 2 Testing')

plt.plot(x, loss_1_test_non, color = 'r', label = 'Loss 1 Testing Non Adaptive')
plt.plot(x, loss_2_test_non, color = 'g', label = 'Loss 2 Testing Non Adaptive')
# plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel(r'Loss function')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 8))

plt.plot(x, acc_1_test, color = 'blue', label = 'Acc 1 Testing')
plt.plot(x, acc_2_test, color = 'black', label = 'Acc 2 Testing')

plt.plot(x, acc_1_test_non, color = 'r', label = 'Acc 1 Testing Non Adaptive')
plt.plot(x, acc_2_test_non, color = 'g', label = 'Acc 2 Testing Non Adaptive')
# plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel(r'Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# %%
Test_acc_PMTL = []
Test_acc_proposed = []

print("Proposed")
for i in test_accs_pref:
  print(i[-1])
  Test_acc_proposed.append(list(i[-1]))

print("PMTL")
for i in test_accs_pref_non:
  print(i[-1])
  Test_acc_PMTL.append(list(i[-1]))

Test_acc_proposed = np.array(Test_acc_proposed)
Test_acc_PMTL = np.array(Test_acc_PMTL)

hv = Hypervolume(ref_point=np.array([1, 1]))
print("Hyper Volume proposed", hv(Test_acc_proposed))
print("Hyper Volume PMTL", hv(Test_acc_PMTL))
# Out:
# Proposed
# [0.82245169 0.87210928]
# [0.80875551 0.87071098]
# [0.83962569 0.86769926]
# [0.86196264 0.86199849]
# [0.86285899 0.85952458]
# PMTL
# [0.79075687 0.81911728]
# [0.78283317 0.81761142]
# [0.80735721 0.81216163]
# [0.83263418 0.79925424]
# [0.85583163 0.76558747]
# Hyper Volume proposed 0.026335008939188272
# Hyper Volume PMTL 0.04767255211803158

# %%
plt.scatter(Test_acc_proposed[:, 0], Test_acc_proposed[:, 1], c = 'blue', label = 'Ours')
plt.scatter(Test_acc_PMTL[:, 0], Test_acc_PMTL[:, 1], c = 'red', label = 'PMTL')
plt.xlabel('Task 1')
plt.ylabel('Task 2')
y1 = [0.88, 0.88]  # Đường thẳng y = 0.88

# Định nghĩa đường thẳng x = 0.91
x2 = [0.85, 0.85]  # Đường thẳng x = 0.91
y2 = [0, 1]  # Chọn khoảng giá trị y từ -1 đến 1

# Vẽ đồ thị
plt.plot(y1, 'g--', label='Single Task')  # Đường thẳng nét đứt đỏ
plt.plot(x2,y2, 'g--')  # Đường thẳng nét đứt xanh
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #Learning_Rate

# %%
learning_rate_pref
# Out:
# [[0.005,
#   0.00495,
#   0.0049005,
#   0.004851495,
#   0.00480298005,
#   0.0047549502495,
#   0.004707400747005,
#   0.00466032673953495,
#   0.0046137234721396,
#   0.004567586237418204,
#   0.004521910375044022,
#   0.004476691271293582,
#   0.004431924358580646,
#   0.00438760511499484,
#   0.004343729063844891,
#   0.004300291773206443,
#   0.0042572888554743785,
#   0.004214715966919635,
#   0.004172568807250438,
#   0.0041308431191779335,
#   0.004089534687986154,
#   0.004048639341106292,
#   0.00400815294769523,
#   0.003968071418218277,
#   0.0039283907040360945,
#   0.0038891067969957335,
#   0.003850215729025776,
#   0.0038117135717355183,
#   0.003773596436018163,
#   0.0037358604716579815,
#   0.003698501866941402,
#   0.003661516848271988,
#   0.003624901679789268,
#   0.0035886526629913752,
#   0.0035527661363614614,
#   0.003517238474997847,
#   0.0034820660902478684,
#   0.00344724542934539,
#   0.003412772975051936,
#   0.0033786452453014168,
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 8))

plt.plot(learning_rate_pref[0] , color = 'blue', label = 'Learning rate Adaptive')
# plt.plot(learning_rate_non, color = 'black', label = 'Learning rate non Adaptive')

# plt.yscale('log')
plt.xlabel('Update Time')
plt.ylabel(r'Learning Rate')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#run(dataset = 'fashion', base_model = 'lenet', niter = 100, npref = 5)
#run(dataset = 'fashion_and_mnist', base_model = 'lenet', niter = 100, npref = 5)

#run(dataset = 'mnist', base_model = 'resnet18', niter = 20, npref = 5)
#run(dataset = 'fashion', base_model = 'resnet18', niter = 20, npref = 5)
#run(dataset = 'fashion_and_mnist', base_model = 'resnet18', niter = 20, npref = 5)
